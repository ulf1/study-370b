# %%
import glob
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# FOLDERS = sorted(glob.glob("best-model-*"))
# FOLDERS

# %%
# FOLDERS = ['best-model-370c-1-1', 'best-model-370c-1-0', 'best-model-370c-0-1']
FOLDERS = [
    'best-model-370b-1-1', 
    'best-model-370b-siamese-1-1', 
    'best-model-370c-1-1', #'best-model-370c-1-0', 'best-model-370c-0-1'
]

for PATH in FOLDERS:
    dat = json.load(open(f"{PATH}/history.json", "r"))
    plt.plot(dat['val_loss'], label=PATH)

plt.yscale('log')
plt.legend()
plt.show()

# %%
PATH = 'best-model-370b-siamese-1-1'
dat = json.load(open(f"{PATH}/history.json", "r"))
plt.plot(dat['val_loss1_rank_triplet'], label='val_loss1_rank_triplet')
plt.plot(dat['val_loss2_mse_target'], label='val_loss2_mse_target')
plt.plot(dat['val_corr_outputs_regulizer'], label='val_corr_outputs_regulizer')
plt.yscale('log')
plt.legend()
plt.show()

# %%
PATH = 'best-model-370b-1-1'
dat = json.load(open(f"{PATH}/history.json", "r"))
plt.plot(dat['val_loss'], label='val_loss')
plt.plot(dat['val_corr_outputs_regulizer'], label='val_corr_outputs_regulizer')
plt.yscale('log')
plt.legend()
plt.show()

# %%
PATH = 'best-model-370c-1-1'
dat = json.load(open(f"{PATH}/history.json", "r"))
# plt.plot(dat['val_model_1_loss'], label='val_model_1_loss')
# plt.plot(dat['val_model_2_loss'], label='val_model_2_loss')
plt.plot(dat['val_corr_outputs_regularizer_loss'], label='val_model_regr')
# plt.plot(dat['val_corr_outputs_regulizer'], label='val_corr_outputs_regulizer')
plt.yscale('log')
plt.legend()
plt.show()

# %%
FOLDERS = [
    'best-model-370b-1-1', 
    'best-model-370b-siamese-1-1', 
    'best-model-370c-1-1',
]

for PATH in FOLDERS:
    dat = json.load(open(f"{PATH}/history.json", "r"))
    plt.plot(dat['val_corr_outputs_regulizer'], label=PATH)

plt.yscale('log')
plt.legend()
plt.show()

# %%
FOLDERS = ['best-model-370c-1-1', 'best-model-370c-1-0', 'best-model-370c-0-1']

for PATH in FOLDERS:
    dat = json.load(open(f"{PATH}/history.json", "r"))
    plt.plot(dat['val_model_1_loss'], label=PATH)

plt.yscale('log')
plt.legend()
plt.show()

# %%
FOLDERS = ['best-model-370c-1-1', 'best-model-370c-1-0', 'best-model-370c-0-1']

for PATH in FOLDERS:
    dat = json.load(open(f"{PATH}/history.json", "r"))
    plt.plot(dat['val_model_2_loss'], label=PATH)

plt.yscale('log')
plt.legend()
plt.show()
